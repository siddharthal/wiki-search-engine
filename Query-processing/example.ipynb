# %%
import math

fa = open('/scratch/siddhartha.l/20000/bytearray.txt','r')
fb = open('/scratch/siddhartha.l/20000/body.txt','r')
fc = open('/scratch/siddhartha.l/20000/cat.txt','r')
fi = open('/scratch/siddhartha.l/20000/info.txt','r')
fr = open('/scratch/siddhartha.l/20000/ref.txt','r')
fl = open('/scratch/siddhartha.l/20000/link.txt','r')
ft = open('/scratch/siddhartha.l/20000/title.txt','r')
fm = open('/scratch/siddhartha.l/20000/main_index.txt','r')
fd = open('/scratch/siddhartha.l/file.txt','r')

di = {}
ndoc = float(17600000)

# %%
bytes = fa.readlines()
for line in bytes:
	k = line.split('|')
	key = k.pop(0)
	li = []
	for i in k:
		if(i == ''):
			li.append([])
			continue
		i = i.split('-')
		li.append([int(i[0]),int(i[1])])
	di[key] = li[:]

# %%
filedi = {}
try:
	while(1):
		byte = fd.tell()
		line = fd.readline()
		line = line.split()
		fre = line[len(line) -1 ].split('|')
		filedi[line.pop(0)] = [byte,int(fre[1])]
except:
	pass

# %%
import time
import Stemmer
stemmer = Stemmer.Stemmer('english')
import re

k = 1.5
b = 0.75
davg = 418

# %%
top_hits = {}

def scorer(fp, q, pos):
    global top_hits
    print (q)
    q = re.sub(r'[^a-zA-Z0-9]+', ' ', q).lower().split()
    for word in q:        
        try:
            byte = di[stemmer.stemWord(word)][pos]
        except:
            continue
        
        fp.seek(byte[1])
        line = fp.readline()
        idf = math.log(byte[0]/ndoc)
        line = line.split()
        line.pop(0)
        for doc in line:
            d = doc.split('|')
            if(int(d[1]) is 0):
                continue
                
            if(d[0] in top_hits):
                top_hits[d[0]][1] += (1 + math.log(int(d[1]))) * idf
                top_hits[d[0]][0] += 1
            else:
                tf_idf = (1 + math.log(int(d[1]))) * idf
                top_hits[d[0]] = [1,tf_idf]
    
while(1):
    top_hits = {}
    print("Field|General(f|g)?")
    c = raw_input()
    if (c == 'g'):
        query = raw_input()
    else:
        print ("title:")
        ts = raw_input()
        print ("body:")
        bs = raw_input()
        print ("categories:")
        cs = raw_input()
        print ("infobox:")
        si = raw_input()
        print ("refernces:")
        rs = raw_input()
        print ("links:")
        ls = raw_input()
    
    start = time.time()
    if(c == 'f'):
        scorer(ft,ts,5)
        scorer(fb,bs,0)
        scorer(fc,cs,1)
        scorer(fr,rs,2)
        scorer(fl,ls,3)
        scorer(fi,si,4)        
        
    else:
        query = re.sub(r'[^a-zA-Z0-9]+', ' ', query).lower().split()
        for word in query:
            try:
                byte = di[stemmer.stemWord(word)][6]
            except:
                continue

            fm.seek(byte[1])
            line = fm.readline()
            idf = math.log((ndoc - byte[0] + 0.5)/(byte[0] + 0.5))
            line = line.split()
            line.pop(0)
            for doc in line:
                d = doc.split('|')
                if(int(d[1]) is 0):
                    continue
                doclen = filedi[d[0]][1]
                tf = 1 + (int(d[1])/float(doclen))
                okapi = (tf*(k+1)/(tf + k*((1 - b) + b*(doclen/davg))))
                score = okapi * idf

                if(d[0] in top_hits):
                    top_hits[d[0]][1] += score
                    top_hits[d[0]][0] += 1
                else:
                    tf_idf = score
                    top_hits[d[0]] = [1,tf_idf]
    
    results = top_hits.keys()
    results.sort(key = lambda x: (top_hits[x][0],top_hits[x][1]), reverse = True)
    
    for hit in results[:5000]: 
        title = ""
        fd.seek(filedi[hit][0])
        lin = fd.readline()
        lin = lin.split()
        for j in range(1,len(lin) -1 ):
            title += (lin[j] + " ")
        title += lin[len(lin) - 1].split('|')[0]
        title = title.lower().split()
        tl = len(title)
        q = query[:]
        for t in title:
            if t not in q:
                q.append(t)
        aub =  len(q)
        anb =  tl +  len(query) - len(q)
        trust = 1 + (anb/aub)
        top_hits[hit][1] *= trust
    
    results.sort(key = lambda x: (top_hits[x][0],top_hits[x][1]), reverse = True)

    for i in results[:10]:
        fd.seek(filedi[i][0])
        lin = fd.readline()
        lin = lin.split()
        str = ""
        for j in range(len(lin) -1 ):
            str += (lin[j] + " ")
        str += lin[len(lin) - 1].split('|')[0]
        print (str)
    print "Time :", time.time() - start
# Out:
# Field|General(f|g)?
# g
# Sachin Tendulkar
# 35877360 Sachin Tendulkar records
# 9949732 Sachin r tendulkar
# 36574562 Shachin Tendulkar
# 8814780 SR Tendulkar
# 9949728 S R Tendulkar
# 32690484 S Tendulkar
# 17640380 S. R. Tendulkar
# 9267218 Sachin Tandulkar
# 45398937 Sachin Tendukar
# 23954294 Sachin the maestro
# Time : 0.0578701496124
# Field|General(f|g)?
# g
# tendulkar sachin
# 35877360 Sachin Tendulkar records
# 9949732 Sachin r tendulkar
# 32690484 S Tendulkar
# 36574562 Shachin Tendulkar
# 8814780 SR Tendulkar
# 9949728 S R Tendulkar
# 17640380 S. R. Tendulkar
# 9267218 Sachin Tandulkar
# 45398937 Sachin Tendukar
# 23954294 Sachin the maestro
# Time : 0.0484139919281
# Field|General(f|g)?
# g
# Barack Obama
# 34061449 Obama barack
# 15617159 Obama Barack
# 8921357 Barack obama
# 28651070 BARACK OBAMA
# 2338091 Barack H Obama
# 9082852 Barack H Obama, Jr
# 9082851 Barack H Obama, Jr.
# 9082855 Barack H Obama Jr.
# 34005342 Barack Hussein obama
# 9082809 Barack Hussein Obama Jr
# Time : 0.252061843872
# Field|General(f|g)?
# g
# Prime Minister of India
# 305010 Rahul Gandhi
# 5504413 Fodder Scam
# 461913 Liaquat Ali Khan
# 36932705 History of the Islamic Republic of Pakistan
# 36575610 Cabinet Committee on Security
# 797711 Union Council of Ministers
# 49216706 Template:Union ministries of India
# 2007608 Deputy Prime Minister of India
# 38856953 Chandra Shekhar ministry
# 15564736 Principal Secretary (India)
# Time : 0.539535999298
# Field|General(f|g)?
# g
# president of india
# 36932705 History of the Islamic Republic of Pakistan
# 22034559 Wikipedia:WikiProject Missing encyclopedic articles/DNB Epitome 52
# 5855481 Wikipedia:Articles for creation/2006-07-06
# 12517460 Template:Lists of Presidents of India
# 43304300 Template:Presidencies and provinces of British India
# 3413197 Hernando Siles Reyes
# 38365482 Pavan Varma
# 48517854 Old Presidency
# 4415609 Stephanus Schoeman
# 12559103 List of Vice-Presidents of India
# Time : 0.344671964645
# Field|General(f|g)?
# f
# title:
# Sachin
# body:
#
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# Sachin
#
#
#
#
#
# 2997051 Wikipedia:Articles for deletion/Chris And Sachin: The Aldehydes
# 35137929 Gourmohan Sachin Mondal Mahavidyalaya
# 39522256 Wikipedia:Articles for deletion/Achievements of Sachin Tendulkar
# 20817418 Sachin Khedekar
# 42407971 Sachin Tendulkar alla
# 51151763 Draft:Sachin sutariya
# 20408026 Wikipedia:Featured article candidates/Sachin Tendulkar/archive1
# 48088353 File:Sachin at Vasai Virar Marathon.png
# 25941578 List of Test Match centuries by Sachin Tendulkar
# 53779433 Sachin-Shoaib cricket rivalry
# Time : 0.00594401359558
# Field|General(f|g)?
# f
# title:
# sachin
# body:
#
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# sachin
#
#
#
#
#
# 2997051 Wikipedia:Articles for deletion/Chris And Sachin: The Aldehydes
# 35137929 Gourmohan Sachin Mondal Mahavidyalaya
# 39522256 Wikipedia:Articles for deletion/Achievements of Sachin Tendulkar
# 20817418 Sachin Khedekar
# 42407971 Sachin Tendulkar alla
# 51151763 Draft:Sachin sutariya
# 20408026 Wikipedia:Featured article candidates/Sachin Tendulkar/archive1
# 48088353 File:Sachin at Vasai Virar Marathon.png
# 25941578 List of Test Match centuries by Sachin Tendulkar
# 53779433 Sachin-Shoaib cricket rivalry
# Time : 0.003662109375
# Field|General(f|g)?
# f
# title:
# sachin
# body:
# cricket
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# sachin
# cricket
#
#
#
#
# 46695008 Sachin Mylavarapu
# 38719115 Sachin Baby
# 10214916 List of ODI awards for Sachin Tendulkar
# 53776843 Sachin–Shoaib cricket rivalry
# 14669888 Achievements of Sachin Tendulkar
# 15448199 List of international cricket centuries by Sachin Tendulkar
# 57570 Sachin Tendulkar
# 5908095 Sachin Sengupta
# 16941961 Sachin Shroff
# 35099061 File:Sachin Tendulkar cropped.jpg
# Time : 0.15311217308
# Field|General(f|g)?
# f
# title:
# sachin tendulkar
# body:
#
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# sachin tendulkar
#
#
#
#
#
# 39522256 Wikipedia:Articles for deletion/Achievements of Sachin Tendulkar
# 42407971 Sachin Tendulkar alla
# 25941578 List of Test Match centuries by Sachin Tendulkar
# 15448199 List of international cricket centuries by Sachin Tendulkar
# 41022884 Category:Sachin Tendulkar
# 15822979 Wikipedia:Peer review/List of ODI Awards for Sachin Tendulkar
# 10214931 List of ODI Man of the Match Awards for Sachin Tendulkar
# 15866602 Wikipedia:Featured list candidates/List of Test cricket centuries by Sachin Tendulkar
# 35099061 File:Sachin Tendulkar cropped.jpg
# 21221965 List of ODI Awards for Sachin Tendulkar
# Time : 0.00521802902222
# Field|General(f|g)?
# f
# title:
# modi
# body:
#
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# modi
#
#
#
#
#
# 37295079 Wikipedia:Articles for deletion/Narendra Modi's Google+ Hangout
# 45367238 Asit Kumarr Modi
# 36464115 Bai Modi Joof
# 31094491 Modis Building
# 47407598 File:Jashodaben Narendrabhai Modi painted.jpg
# 36193409 Sir Homi Mody
# 14378700 Emperor modi of western xia
# 44710688 Template:Modi ministry
# 11597291 Dr. K.N.Modi institute of Engineering & Technology
# 21669486 Ouro Modi
# Time : 0.00613689422607
# Field|General(f|g)?
# f
# title:
# modi
# body:
# india
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# modi
# india
#
#
#
#
# 44063054 Timeline of the premiership of Narendra Modi
# 42915589 Wikipedia:Articles for deletion/Swearing-in ceremony of Narendra Modi
# 42772255 Modi ministry
# 35678591 Bhupendra Kumar Modi
# 46476169 Public image of Narendra Modi
# 2613630 Rusi Modi
# 54298646 Wikipedia:Articles for deletion/Programs renamed by Modi Government
# 42861537 Swearing-in ceremony of Narendra Modi
# 5240407 Syed Modi
# 44281017 Template:Narendra Modi
# Time : 0.131425142288
# Field|General(f|g)?
# f
# title:
#
# body:
# chocolates
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
#
# chocolates
#
#
#
#
# 244332 The Perishers
# 12319582 Wikipedia:Editor assistance/Requests/Archive 4
# 16061261 Wikipedia:Articles for deletion/BigBellyFilm
# 4215779 Wangechi Mutu
# 11741 Fantasy film
# 2353886 Chocolate stout
# 1766454 Stubborn Kind of Fellow
# 14983019 Wikipedia:Articles for deletion/Ain't That Life (album)
# 8825270 Wikipedia:WikiProject Taxation/Collaboration
# 12501588 Wikipedia:Articles for deletion/Garfio
# Time : 0.123857975006
# Field|General(f|g)?
# g
# 15 august
# 43567515 Wikipedia:Suspected copyright violations/2014-08-15
# 6478094 Wikipedia:Articles for deletion/15 Westferry Circus
# 40639703 Template:Infobox holiday/sandbox
# 28367000 Wikipedia:Suspected copyright violations/2010-08-15
# 43616556 Wikipedia:WikiProject Articles for creation/Help desk/Archives/2014 August 15
# 2457298 Wikipedia:Articles for deletion/Widdifield secondary school
# 32436411 First Nehru ministry
# 994436 Template:Infobox holiday
# 18925702 Wikipedia:Reference desk/Archives/Language/2008 August 15
# 51370342 Wikipedia:Help desk/Archives/2016 August 15
# Time : 0.344492912292
# Field|General(f|g)?
# f
# title:
# august
# body:
# 15 august
# categories:
#
# infobox:
#
# refernces:
#
# links:
#
# august
# 15 august
#
#
#
#
# 43599793 Wikipedia:Help desk/Archives/2014 August 15
# 40281966 Wikipedia:Reference desk/Archives/Science/2013 August 15
# 44167191 CMLL Super Viernes (August 2014)
# 40243893 Wikipedia:Files for deletion/2013 August 15
# 28403914 Wikipedia:Help desk/Archives/2010 August 15
# 28366177 Wikipedia:Files for deletion/2010 August 15
# 51370342 Wikipedia:Help desk/Archives/2016 August 15
# 18925702 Wikipedia:Reference desk/Archives/Language/2008 August 15
# 51183055 List of United States tornadoes from June to August 2016
# 13035257 Wikipedia:Peer review/Automated/August 2007
# Time : 0.297088861465
# Field|General(f|g)?
